# %% [markdown]
# # Confusion Matrices and Expected Value
#
# This notebook demonstrates how to use `ConfusionMatrix` in CUAnalytics to:
#
# - inspect confusion matrix layouts (`normal` and `inverted`)
# - retrieve confusion-matrix metrics
# - compute expected value from a cost/benefit matrix

# %%
import pandas as pd
import cuanalytics as ca

# %% [markdown]
# ## 1) Build a ConfusionMatrix from labels

# %%
y_true = ['No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
y_pred = ['No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes']

cm = ca.ConfusionMatrix(y_true, y_pred, labels=['No', 'Yes'])
cm.to_dataframe(display='normal')
# Out:
#             Pred No  Pred Yes
# Actual No         4         1
# Actual Yes        2         3

# %%
# Inverted display swaps the table orientation for presentation only
cm.to_dataframe(display='inverted')
# Out:
#           Actual Yes  Actual No
# Pred Yes           3          1
# Pred No            2          4

# %% [markdown]
# ## 1b) Print a readable summary
#
# Use `summary()` for a console-style confusion matrix report.

# %%
cm.summary()
# Out:
# Confusion Matrix and Statistics
# ============================================================
#
# Confusion Matrix:
#           Actual Yes  Actual No
# Pred Yes           3          1
# Pred No            2          4
#
# Overall Statistics:
# Accuracy            0.7000
# Kappa               0.4000
# Macro Precision     0.7083
# Macro Recall        0.7000
# Macro Specificity   0.7000
# Macro F1            0.6970
# Precision           0.7500
# Recall              0.6000
# Sensitivity         0.6000
# Specificity         0.8000
# FPR                 0.2000
# FNR                 0.4000
# F-measure           0.6667
#
# Binary Counts (Positive = 'Yes'):
# TP: 3  FP: 1  FN: 2  TN: 4
#
# Statistics by Class:
#      precision  recall  sensitivity  specificity     f1
# No      0.6667  0.8000       0.8000       0.6000 0.7273
# Yes     0.7500  0.6000       0.6000       0.8000 0.6667
#           Actual Yes  Actual No
# Pred Yes           3          1
# Pred No            2          4

# %% [markdown]
# ## 2) Retrieve confusion matrix metrics

# %%
metrics = cm.get_metrics()

summary_fields = {
    'accuracy': metrics['accuracy'],
    'kappa': metrics['kappa'],
    'precision': metrics['precision'],
    'recall': metrics['recall'],
    'sensitivity': metrics['sensitivity'],
    'specificity': metrics['specificity'],
    'tpr': metrics['tpr'],
    'fpr': metrics['fpr'],
    'f_measure': metrics['f_measure'],
    'binary_counts': metrics['binary_counts']
}
pd.Series(summary_fields)
# Out:
# accuracy                                          0.7
# kappa                                             0.4
# precision                                        0.75
# recall                                            0.6
# sensitivity                                       0.6
# specificity                                       0.8
# tpr                                               0.6
# fpr                                               0.2
# f_measure                                    0.666667
# binary_counts    {'tp': 3, 'fp': 1, 'fn': 2, 'tn': 4}
# dtype: object

# %% [markdown]
# ## 3) Compute expected value
#
# `get_expected_value(costs)` uses the same layout as the default confusion-matrix display (`inverted`).
#
# For binary labels `['No', 'Yes']`, the expected layout is:
#
# - rows = predicted class
# - columns = actual class
# - top-left = TP
# - top-right = FP
# - bottom-left = FN
# - bottom-right = TN

# %%
# Costs follow the default inverted layout:
# [[TP, FP],
#  [FN, TN]]
costs = [
    [8.0, -5.0],
    [-20.0, 1.0]
]

ev = cm.get_expected_value(costs)
print(f'Expected value per observation: {ev:.3f}')
# Out:
# Expected value per observation: -1.700

# %% [markdown]
# ## 4) Use ConfusionMatrix from a fitted model

# %%
df = ca.load_breast_cancer_data()
train_df, test_df = ca.split_data(df, test_size=0.25, random_state=42)

model = ca.fit_logit(train_df, formula='diagnosis ~ .')
test_cm = model.get_confusion_matrix(test_df)

# Display with normal orientation
test_cm.to_dataframe(display='normal')
# Out:
# Logistic Regression fitted successfully!
#   Classes: ['B', 'M']
#   Features: 30
#   Training samples: 426
#   C parameter: 1.0
#   Solver: lbfgs
#           Pred B  Pred M
# Actual B      87       2
# Actual M       3      51

# %%
# Display with inverted orientation
test_cm.to_dataframe(display='inverted')
# Out:
#         Actual M  Actual B
# Pred M        51         2
# Pred B         3        87

# %%
test_metrics = test_cm.get_metrics()
pd.Series({
    'accuracy': test_metrics['accuracy'],
    'kappa': test_metrics['kappa'],
    'precision': test_metrics.get('precision', float('nan')),
    'recall': test_metrics.get('recall', float('nan')),
    'specificity': test_metrics.get('specificity', float('nan')),
    'f_measure': test_metrics.get('f_measure', float('nan')),
})
# Out:
# accuracy       0.965035
# kappa          0.925342
# precision      0.962264
# recall         0.944444
# specificity    0.977528
# f_measure      0.953271
# dtype: float64

# %%
# Example expected-value setup for this model's confusion matrix.
# Adjust these numbers to reflect your business context.
costs_model = [
    [1.0, -10.0],
    [-25.0, 12.0]
]

ev_model = test_cm.get_expected_value(costs_model)
print(f'Model expected value per observation: {ev_model:.3f}')
# Out:
# Model expected value per observation: 6.993

# %%
df = ca.load_breast_cancer_data()
print(df.head())
train_df, test_df = ca.split_data(df, test_size=0.25, random_state=42)
model = ca.fit_logit(train_df, formula='diagnosis ~ .')
model.summary()
test_cm = model.get_confusion_matrix()
test_cm.summary()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  diagnosis
# 0          0.4601                  0.11890          M
# 1          0.2750                  0.08902          M
# 2          0.3613                  0.08758          M
# 3          0.6638                  0.17300          M
# 4          0.2364                  0.07678          M
#
# [5 rows x 31 columns]
#
# Logistic Regression fitted successfully!
#   Classes: ['B', 'M']
#   Features: 30
#   Training samples: 426
#   C parameter: 1.0
#   Solver: lbfgs
#
# ======================================================================
# LOGISTIC REGRESSION MODEL SUMMARY
# ======================================================================
#
# MODEL INFORMATION:
# ----------------------------------------------------------------------
# Target: diagnosis
# Number of features: 30
# Classes: ['B', 'M']
# Training samples: 426
# C parameter: 1.0
# Solver: lbfgs
#
# TRAINING FIT:
# ----------------------------------------------------------------------
# Training Accuracy: 96.24%
#
# Training Confusion Matrix:
#         Actual M  Actual B
# Pred M       148         6
# Pred B        10       262
#
# Per-Class Metrics:
#    precision  recall  sensitivity  specificity     f1
# B     0.9632  0.9776       0.9776       0.9367 0.9704
# M     0.9610  0.9367       0.9367       0.9776 0.9487
#
# Kappa: 0.9191
#
# COEFFICIENTS:
# ----------------------------------------------------------------------
# class                 feature  coefficient  z_score  p_value significance
#     M             (Intercept)     -31.5525  -1.4934   0.1353
#     M             mean radius      -1.0891  -0.1329   0.8943
#     M            mean texture      -0.2351  -1.0586   0.2898
#     M          mean perimeter       0.4240   0.3845   0.7006
#     M               mean area      -0.0286  -0.9539   0.3401
#     M         mean smoothness       0.1385   0.0019   0.9985
#     M        mean compactness       0.2453   0.0047   0.9962
#     M          mean concavity       0.5197   0.0138   0.9890
#     M     mean concave points       0.2758   0.0038   0.9969
#     M           mean symmetry       0.2153   0.0088   0.9930
#     M  mean fractal dimension       0.0397   0.0002   0.9998
#     M            radius error       0.1251   0.0055   0.9956
#     M           texture error      -1.4231  -0.8617   0.3888
#     M         perimeter error      -0.3987  -0.2175   0.8278
#     M              area error       0.1429   0.6606   0.5089
#     M        smoothness error       0.0187   0.0001   0.9999
#     M       compactness error      -0.0028  -0.0000   1.0000
#     M         concavity error       0.0688   0.0009   0.9992
#     M    concave points error       0.0339   0.0001   0.9999
#     M          symmetry error       0.0446   0.0005   0.9996
#     M fractal dimension error      -0.0005  -0.0000   1.0000
#     M            worst radius      -0.0966  -0.0371   0.9704
#     M           worst texture       0.5133   2.2709   0.0232            *
#     M         worst perimeter       0.0404   0.1698   0.8652
#     M              worst area       0.0134   0.5078   0.6116
#     M        worst smoothness       0.2814   0.0060   0.9952
#     M       worst compactness       0.7627   0.0578   0.9539
#     M         worst concavity       1.3797   0.1286   0.8977
#     M    worst concave points       0.4929   0.0129   0.9897
#     M          worst symmetry       0.7269   0.0506   0.9597
#     M worst fractal dimension       0.1057   0.0012   0.9991
#
# Note: z-scores and p-values use a normal approximation;
#       multiclass values are computed one-vs-rest.
#
# ======================================================================
#
# Confusion Matrix and Statistics
# ============================================================
#
# Confusion Matrix:
#         Actual M  Actual B
# Pred M       148         6
# Pred B        10       262
#
# Overall Statistics:
# Accuracy            0.9624
# Kappa               0.9191
# Macro Precision     0.9621
# Macro Recall        0.9572
# Macro Specificity   0.9572
# Macro F1            0.9595
# Precision           0.9610
# Recall              0.9367
# Sensitivity         0.9367
# Specificity         0.9776
# FPR                 0.0224
# FNR                 0.0633
# F-measure           0.9487
#
# Binary Counts (Positive = 'M'):
# TP: 148  FP: 6  FN: 10  TN: 262
#
# Statistics by Class:
#    precision  recall  sensitivity  specificity     f1
# B     0.9632  0.9776       0.9776       0.9367 0.9704
# M     0.9610  0.9367       0.9367       0.9776 0.9487
#         Actual M  Actual B
# Pred M       148         6
# Pred B        10       262
