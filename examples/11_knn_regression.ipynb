# %% [markdown]
# # k-Nearest Neighbors (Regression)

# %% [markdown]
# Use KNN to predict a continuous outcome based on nearby points.

# %% [markdown]
# ## Setup: Load the Real Estate Dataset

# %%
import cuanalytics

# %%
# Load data and create train/test split
df = cuanalytics.load_real_estate_data()
train_df, test_df = cuanalytics.split_data(df, test_size=0.2, random_state=42)
train_df.head()

# %% [markdown]
# ## Step 1: Fit a KNN Regressor

# %%
knn = cuanalytics.fit_knn_regressor(train_df, formula='price_per_unit ~ .', k=5)

# %% [markdown]
# ## Step 2: Evaluate Performance

# %%
metrics = knn.score(test_df)
print(f"Test R²: {metrics['r2']:.4f}")
print(f"Test RMSE: {metrics['rmse']:.4f}")

# %% [markdown]
# ## Step 3: Summary

# %%
knn.summary()

# %% [markdown]
# ## 🎓 Your Turn

# %% [markdown]
# - Try different values of k and compare R².
# - Compare KNN to linear regression on the same dataset.
